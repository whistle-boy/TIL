# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "YOUR_CLIENT_ID"
client_secret = "YOUR_CLIENT_SECRET"
encText = urllib.parse.quote("검색할 단어")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# %%
import os
import sys
import urllib.request
encText = urllib.parse.quote("패캠")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Tue, 27 Oct 2020 20:30:17 +0900",
# "total": 1610,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "[<b>패캠</b> 학습일지] 게임 기획 (모바일 게임 시장에 대한 생각)",
# "link": "https:\/\/blog.naver.com\/shingun_nav?Redirect=Log&logNo=221596728152",
# "description": "요즘 <b>패캠</b> 강의를 정말 듣고 정말 열심히 블로그 쓰고 있습니다. ㅎㅎㅎ <b>패캠</b> 게임 기획 강의를 들어봤습니다. 개인적으로 기획에 대해 배울 것이 많을 것 같아서 기대가 컸었죠. 하지만 초반 강의는 아케이드... ",
# "bloggername": "아이디어샘 (VOCAKOREA.COM)",
# "bloggerlink": "https://blog.naver.com/shingun_nav",
# "postdate": "20190726"
#
# },
# {
# "title": "<b>패캠</b>(패스트캠퍼스) iOS 입문 온라인 강의 후기",
# "link": "https:\/\/blog.naver.com\/psj9102?Redirect=Log&logNo=222119030177",
# "description": "# <b>패캠</b>으로 시작하게 된 계기 다른 강의를 많이 찾아봤지만 <b>패캠</b>이 가장 적당한 가격과 커리큘럼을 가지고 있는 것 같습니다. 그리고 iOS 에 대한 강의가 그렇게 많지도 않습니다. ( 제가 찾아본 바로는 ) 개발... ",
# "bloggername": "비전공자 개발 블로그",
# "bloggerlink": "https://blog.naver.com/psj9102",
# "postdate": "20201018"
#
# },
# {
# "title": "[<b>패캠</b>후기] 컴퓨터 공학 올인원 패키지",
# "link": "https:\/\/blog.naver.com\/asp_pd?Redirect=Log&logNo=221604400877",
# "description": "S/W를 배우기 위해서 복수전공을 고민했지만 H/W만 듣기에도 학점이 모자르기 때문에 <b>패캠</b>을 신청하게 되었다. <b>패캠</b> 강의에서도 '컴퓨터 공학 올인원 패키지'를 골랐다. 정말 듣고 싶은 과목이 많다. 웹개발... ",
# "bloggername": "아이오티 라이프 스토리",
# "bloggerlink": "https://blog.naver.com/asp_pd",
# "postdate": "20190803"
#
# },
# {
# "title": "모바일 앱 개발 비전공자 앱 만들기 취업 가능해요 <b>패캠</b> 후기",
# "link": "https:\/\/blog.naver.com\/wjsqhfka73?Redirect=Log&logNo=221609127992",
# "description": "모바일 앱 개발 비전공자 앱 만들기 <b>패캠</b> 과정은 한 번 강의를 수강하면 무기한으로 소장해 들을 수 있습니다. 취업해서 생각나지 않는 부분이 있을 때, 헷갈릴 때 등등 두고두고 보면서 자기계발이 가능해요.... ",
# "bloggername": "우리들의 꿈돋움터",
# "bloggerlink": "https://blog.naver.com/wjsqhfka73",
# "postdate": "20190807"
#
# },
# {
# "title": "<b>패캠</b> 디지털 마케팅 독학 완주반 후기 / 환급반",
# "link": "https:\/\/blog.naver.com\/happying0405?Redirect=Log&logNo=222066331489",
# "description": "그래서 <b>패캠</b> 선생님 강의를 듣고 바로 cpc 입찰가를 수정할 수 있었다. 아이패드로 디지털마케팅 완주반... 같은데 <b>패캠</b>은 주차별로 준다고 하니 이것은 누군가의 송금 노력이 나에게 곁들여지는 아름다운 마무리... ",
# "bloggername": "톡이의 Tok_Tok",
# "bloggerlink": "https://blog.naver.com/happying0405",
# "postdate": "20200820"
#
# },
# {
# "title": "[리뷰 | <b>패캠</b>] 컴퓨터공학 올인원 패키지(2)",
# "link": "https:\/\/blog.naver.com\/sally932?Redirect=Log&logNo=221570646523",
# "description": "총평 리뷰 1편 보러가기 https://blog.naver.com/sally932/221570599195 <b>패캠</b> 프로그래밍 분야 올인원 패키지 3.... 하지만 <b>패캠</b>에서는 이 패키지를 입문자용으로도 추천하고 있다. 나도 그래서 입문 정도의 난이도를... ",
# "bloggername": "글쓰는 개발자",
# "bloggerlink": "https://blog.naver.com/sally932",
# "postdate": "20190625"
#
# },
# {
# "title": "마지막 [<b>패캠</b>후기] 감사합니다 패스트 캠퍼스!",
# "link": "https:\/\/blog.naver.com\/ll_lv_v?Redirect=Log&logNo=221648009767",
# "description": "패스트 캠퍼스 온라인 강의를 수강하며 가장 좋았던 점 내가 <b>패캠</b> 온라인강의를 수강하며 가장 좋았던 점은 아무래도 딱딱한 작업이 아닌 실무위주의 작업, 그리고 재미있고 흥미로운 작업을 할수 있었던... ",
# "bloggername": "공부로그",
# "bloggerlink": "https://blog.naver.com/ll_lv_v",
# "postdate": "20190914"
#
# },
# {
# "title": "<b>패캠</b> 학습일지 Day16",
# "link": "https:\/\/blog.naver.com\/ujin054?Redirect=Log&logNo=221631542123",
# "description": "<b>패캠</b> 학습일지가 벌써 16일차가 되었어요~ 오늘은 직접 과일을 가지고 실습을 해볼 예정이에요~ 첫번째로 포도와 수박이에요!!! 우선, 실습전에 여러가지 방법들을 알려주셨어요. * 스포이드를 통해서 원하는... ",
# "bloggername": "악세사리 쇼핑몰 마르셀라 925",
# "bloggerlink": "https://blog.naver.com/ujin054",
# "postdate": "20190828"
#
# },
# {
# "title": "[<b>패캠</b>후기] 데이터 마케팅 중간 학습 후기/ 수강 후기",
# "link": "https:\/\/blog.naver.com\/j767asde?Redirect=Log&logNo=221612692437",
# "description": "그럼 이것으로 주저리 주저리 데이터 마케팅 중간 평 및 <b>패캠</b>후기를 마치고 다른 포스트에서 다른... 데이터마케팅 #퇴근후하는자기개발 #자기개발을통한발전 #광고전략 #검색엔진마케팅 #<b>패캠</b>후기 #인강중독",
# "bloggername": "Bon Voyage",
# "bloggerlink": "https://blog.naver.com/j767asde",
# "postdate": "20190811"
#
# },
# {
# "title": "엑셀강의 회사보고서 <b>패캠</b> 후기",
# "link": "https:\/\/blog.naver.com\/j7507775?Redirect=Log&logNo=221610238875",
# "description": "<b>패캠</b> 직장인에게 꼭 필요한 필수스킬 3종세트! 사실 제가 사무쪽으로 취직을 하고 싶은데 회계 경리의... 그런데 <b>패캠</b>에서는 엑셀 활용에 필요한 필수 스킬 중심으로 강의가 구성되어 논리 함수 서식 표 차트... ",
# "bloggername": "그린블루",
# "bloggerlink": "https://blog.naver.com/j7507775",
# "postdate": "20190808"
#
# }
# ]
# }

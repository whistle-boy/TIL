# %% [markdown]
# ### zigbang
# - 동이름 입력하면 원룸 매물정보 가져오기
# - 절차
#     - 1. 동이름 > 위도, 경도
#     - 2. 위도, 경도 > geohash
#     - 3. geohash > item ids
#     - 4. item_ids > item datas

# %%
# !pip install geohash2
# Out:
# Requirement already satisfied: geohash2 in c:\users\user\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: docutils>=0.3 in c:\users\user\anaconda3\lib\site-packages (from geohash2) (0.16)

# %%
import geohash2

# %%
# 1. 동이름 > 위도, 경도

# %%
addr = '망원동'
url = 'https://apis.zigbang.com/v2/search?q=망원동&serviceType=원룸'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.text # json 포맷의 데이터가 나왔다
# Out:
# '{"success":true,"code":"200","items":[{"id":4002,"type":"address","name":"망원동","hint":"","description":"서울시 마포구 망원동","lat":37.556785583496094,"lng":126.9013442993164,"zoom":5,"polygon":[],"_score":null,"_source":{"name_length":3,"local1":"서울시","local2":"마포구","local3":"망원동","web_level":15,"web_lat":37.556785583496094,"web_lng":126.9013442993164,"app_level":15,"app_lat":37.556785583496094,"app_lng":126.9013442993164,"법정동코드":"1144012300"},"zoom_level":{"google":15,"daum":4},"zoom_level_v2":{"app":5,"web":4}}],"next":null,"limit":0}'

# %%
data = response.json() # 파싱을 해주자
data
# Out:
# {'success': True,
#  'code': '200',
#  'items': [{'id': 4002,
#    'type': 'address',
#    'name': '망원동',
#    'hint': '',
#    'description': '서울시 마포구 망원동',
#    'lat': 37.556785583496094,
#    'lng': 126.9013442993164,
#    'zoom': 5,
#    'polygon': [],
#    '_score': None,
#    '_source': {'name_length': 3,
#     'local1': '서울시',
#     'local2': '마포구',
#     'local3': '망원동',
#     'web_level': 15,
#     'web_lat': 37.556785583496094,
#     'web_lng': 126.9013442993164,
#     'app_level': 15,
#     'app_lat': 37.556785583496094,
#     'app_lng': 126.9013442993164,
#     '법정동코드': '1144012300'},
#    'zoom_level': {'google': 15, 'daum': 4},
#    'zoom_level_v2': {'app': 5, 'web': 4}}],
#  'next': None,
#  'limit': 0}

# %%
data = response.json()['items'] # 위도, 경도 값이 필요하니 items
data
# Out:
# [{'id': 4002,
#   'type': 'address',
#   'name': '망원동',
#   'hint': '',
#   'description': '서울시 마포구 망원동',
#   'lat': 37.556785583496094,
#   'lng': 126.9013442993164,
#   'zoom': 5,
#   'polygon': [],
#   '_score': None,
#   '_source': {'name_length': 3,
#    'local1': '서울시',
#    'local2': '마포구',
#    'local3': '망원동',
#    'web_level': 15,
#    'web_lat': 37.556785583496094,
#    'web_lng': 126.9013442993164,
#    'app_level': 15,
#    'app_lat': 37.556785583496094,
#    'app_lng': 126.9013442993164,
#    '법정동코드': '1144012300'},
#   'zoom_level': {'google': 15, 'daum': 4},
#   'zoom_level_v2': {'app': 5, 'web': 4}}]

# %%
addr = "망원동"
url = f"https://apis.zigbang.com/v2/search?q={addr}&serviceType=원룸"
response = requests.get(url)
data = response.json()["items"][0]
lat, lng = data["lat"], data["lng"] #위도, 경도
lat, lng
# Out:
# (37.556785583496094, 126.9013442993164)

# %%
# 2. 위도, 경도 > geohash

# %%
geohash = geohash2.encode(lat, lng, precision=5) # precision이 높을 수록 범위가 좁아진다
geohash
# Out:
# 'wydjx'

# %%
# 3. geohash > item ids

# %%
url = f"https://apis.zigbang.com/v2/items?\
deposit_gteq=0&domain=zigbang&geohash={geohash}\
&rent_gteq=0&sales_type_in=전세|월세&service_type_eq=원룸"
response = requests.get(url)
datas = response.json()["items"]
ids = [data["item_id"] for data in datas]
len(ids), ids[:3]
# Out:
# (740, [24308970, 24576267, 24430916])

# %%
# 4. item_ids > item datas

# %%
url = 'https://apis.zigbang.com/v2/items/list'
params = {
    'domain': "zigbang",
    'item_ids': ids,
    'withCoalition': 'true',
}
response = requests.post(url, data=params)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"items":[{"section_type":null,"item_id":24308970,"images_thumbnail":"https://ic.zigbang.com/ic/items/24308970/1.jpg","sales_type":"월세","sales_title":"월세","deposit":1000,"rent":47,"size_m2":22.15,"공급면적":{"m2":22.15,"p":"6.7"},"전용면적":{"m2":22.15,"p":"6.7"},"계약면적":null,"room_type_title":null,"floor":"5","floor_string":"5","building_floor":"9","title":"🌈당산역 신축 벽걸이TV까지 세련된 인테리어☀️","is_first_movein":null,"room_type":"02","address":"영등포구 당산동4가","random_location":{"lat":37.529569018805965,"lng":126.90042596524361},"is_zzim":false,"status":true,"service_type":"원룸","tags":["추천"],"address1":"서울시 영등포구 당산동4가","address2":null,"address3":null,"manage_cost":"7","reg_date":"2020-10-12T16:16:15+09:00","is_new":false},{"section_type":null,"item_id":24576267,"images_thumbnail":"https://ic.zigbang.com/ic/items/24576267/1.jpg","sales_type":"월세","sales_title":"월세","deposit":1000,"rent":50,"size_m2":19.83,"공급면적":{"m2":19.83,"p":"6"},"전용면적":{"m2":19.83,"p":"6"},"계약면적":null,"room_type_title":null,"floor":"6","floor_string":"6","building_floor":"8","title":"🙂 #당산역#역세권#도시뷰 6층 , 벽걸이TV 💕","is_first_movein":null,"room_type":"02","address":"영등포구 당산동4가","random_location":{"lat":37.52908314916879,"lng":126.90042937117032},"is_zzim":false,"status":true,"service_type":"원룸","tags":[],"address1":"서울시 영등포구 당산동4가","address2":null,"address3":null,"manage_cost":"6","reg_date":"2020-11-01T07:48:56+09:00","is_new":true},{"section_type":null,"item_id":24430916,"images_thumbnail":"https://ic.zigbang.com/ic/items/24430916/1.jpg","sales_type":"전세","sales_title":"전세","deposit":7000,"rent":0,"size_m2":16.53,"공급면적":{"m2":16.53,"p":"5"},"전용면적":{"m2":16.53,"p":"5"},"계약면적":null,"room_type_title":null,"floor":"4","floor_string":"4","building_floor":"8","title":"영등포구청역♣ 근저당 없어 보증금 걱정뚝!! 대출안되요.","is_first_movein":null,"room_type":"01","address":"영등포구 당산동4가","random_location":{"lat":37.52959645421682,"lng":126.89762005537686},"is_zzim":false,"status":true,"service_type":"원룸","tags":[],"address1":"서울시 영등포구 당산동4가","address2":null,"address3":null,"manage_cost":"13","reg_date":"2020-10-21T11:08:39+09:00","is_new":false},{"section_type":null,"item_id":24472349,"images_thumbnail":"https://ic.zigbang.com/ic/items/24472349/1.jpg","sales_type":"전세","sales_title":"전세","deposit":9000,"rent":0,"size_m2":19.83,"공급면적":{"m2":19.83,"p":"6"},"전용면적":{"m2":19.83,"p":"6"},"계약면적":null,"room_type_title":null,"floor":"7","floor_string":"7","building_floor":"8","title":"※양평역 원룸 전세※ #전세대출 #대로변 #가성비","is_first_movein":null,"room_type":"01","address":"영등포구 양평동3가","random_location":{"lat":37.52959382605255,"lng":126.89132881837037},"is_zzim":false,"status":true,"service_type":"원룸","tags":[],"address1":"서울시 영등포구 양평동3가","address2":null,"address3":null,"manage_cost":"12","reg_date":"2020-10-23T17:18:06+09:00","is_new":false},{"section_type":null,"item_id":24431547,"images_thumbnail":"https://ic.zigbang.com/ic/items/24431547/1.jpg","sales_type":"월세","sales_title":"월세","deposit":3000,"rent":30,"size_m2":19.83,"공급면적":{"m2":19.83,"p":"6"},"전용면적":{"m2":19.83,"p":"6"},"계약면적":null,"room_type_title":null,"floor":"3","floor_string":"3","building_floor":"7","title":"★6평/채광좋은 오픈형원룸/마트인접/즉시입주★","is_first_movein":null,"room_type":"01","address":"영등포구 당산동","random_location":{"lat":37.5292111229483,"lng":126.90669939785393},"is_zzim":false,"status":true,"service_type":"원룸","tags":["추천"],"address1":"서울시 영등포구 당산동","address2":null,"address3":null,"manage_cost":"6","reg_date":"2020-10-21T11:25:33+09:00","is_new":false},{"section_type":null,"item_id":24521144,"images_thumbnail":"https://ic.zigbang.com/ic/items/24521144/1.jpg","sales_type":"전세","sales_title":"전세","deposit":7500,"rent":0,"size_m2":22.15,"공급면적":{"m2":22.15,"p":"6.7"},"전용면적":{"m2":22.15,"p":"6.7"},"계약면적":null,"room_type_title":null,"floor":"7","floor_string":"7","building_floor":"7","title":"💥💥역세권원룸!大박사이즈!💥💥[풀옵션,엘베有!!]","is_first_movein":null,"room_type":"01","address":"영등포구 당산동","random_location":{"lat":37.52968474724325,"lng":126.90672859710219},"is_zzim":false,"stat ...

# %%
items = response.json()['items']
items[0]
# Out:
# {'section_type': None,
#  'item_id': 24308970,
#  'images_thumbnail': 'https://ic.zigbang.com/ic/items/24308970/1.jpg',
#  'sales_type': '월세',
#  'sales_title': '월세',
#  'deposit': 1000,
#  'rent': 47,
#  'size_m2': 22.15,
#  '공급면적': {'m2': 22.15, 'p': '6.7'},
#  '전용면적': {'m2': 22.15, 'p': '6.7'},
#  '계약면적': None,
#  'room_type_title': None,
#  'floor': '5',
#  'floor_string': '5',
#  'building_floor': '9',
#  'title': '🌈당산역 신축 벽걸이TV까지 세련된 인테리어☀️',
#  'is_first_movein': None,
#  'room_type': '02',
#  'address': '영등포구 당산동4가',
#  'random_location': {'lat': 37.529569018805965, 'lng': 126.90042596524361},
#  'is_zzim': False,
#  'status': True,
#  'service_type': '원룸',
#  'tags': ['추천'],
#  'address1': '서울시 영등포구 당산동4가',
#  'address2': None,
#  'address3': None,
#  'manage_cost': '7',
#  'reg_date': '2020-10-12T16:16:15+09:00',
#  'is_new': False}

# %%
item_df = pd.DataFrame(items)
item_df.tail(2)
# Out:
#     section_type   item_id                                images_thumbnail  \
# 738         None  24584289  https://ic.zigbang.com/ic/items/24584289/1.jpg
# 739         None  24188069  https://ic.zigbang.com/ic/items/24188069/1.jpg
#
#     sales_type sales_title  deposit  rent  size_m2                      공급면적  \
# 738         전세          전세    31000     0    59.50   {'m2': 59.5, 'p': '18'}
# 739         전세          전세    18000     0    33.06  {'m2': 33.06, 'p': '10'}
#
#                          전용면적  ... is_zzim status service_type  tags  \
# 738   {'m2': 56.2, 'p': '17'}  ...   False   True           빌라  [추천]
# 739  {'m2': 33.06, 'p': '10'}  ...   False   True           원룸    []
#
#        address1 address2 address3 manage_cost                   reg_date  \
# 738  서울시 마포구 중동     None     None           5  2020-11-02T11:05:59+09:00
# 739  서울시 마포구 중동     None     None           6  2020-10-26T20:07:57+09:00
#
#     is_new
# 738   True
# 739  False
#
# [2 rows x 30 columns]

# %%
len(item_df.columns) # pandas는 default로 20개까지 나온다 > 다 보고 싶으면 따로 설정이 필요하다
# Out:
# 30

# %%
# 필요한 컬럼만 필터링

# %%
pd.options.display.max_columns = len(item_df.columns)
item_df.tail(2)
# Out:
#     section_type   item_id                                images_thumbnail  \
# 788         None  24560234  https://ic.zigbang.com/ic/items/24560234/1.jpg
# 789         None  24188069  https://ic.zigbang.com/ic/items/24188069/1.jpg
#
#     sales_type sales_title  deposit  rent  size_m2                       공급면적  \
# 788         전세          전세    31000     0    44.10  {'m2': 44.1, 'p': '13.3'}
# 789         전세          전세    18000     0    33.06   {'m2': 33.06, 'p': '10'}
#
#                          전용면적  계약면적 room_type_title floor floor_string  \
# 788  {'m2': 28.7, 'p': '8.7'}  None            None     4            4
# 789  {'m2': 33.06, 'p': '10'}  None            None     4            4
#
#     building_floor                             title is_first_movein  \
# 788              5     가좌역 초역세권 전망좋은 고급 2룸 신축 첫입주 전세            None
# 789              5  ♥[고래복층등장+러블리]♥가좌역5분♥EV+주차+완성형복충♥            None
#
#     room_type address                                    random_location  \
# 788        04  마포구 중동  {'lat': 37.568896834081684, 'lng': 126.9095717...
# 789        01  마포구 중동  {'lat': 37.56995706943952, 'lng': 126.90948156...
#
#      is_zzim  status service_type  tags    address1 address2 address3  \
# 788    False    True           빌라  [추천]  서울시 마포구 중동     None     None
# 789    False    True           원룸    []  서울시 마포구 중동     None     None
#
#     manage_cost                   reg_date  is_new
# 788           5  2020-10-30T14:54:46+09:00    True
# 789           6  2020-10-26T20:07:57+09:00   False

# %%
columns = ['item_id', 'sales_type', 'deposit', 'rent', 'size_m2',
           'floor', 'building_floor', 'title', 'address',
           'manage_cost', 'random_location']

# %%
result_df = item_df[columns]
item_df
# Out:
#     section_type   item_id                                images_thumbnail  \
# 0           None  24308970  https://ic.zigbang.com/ic/items/24308970/1.jpg
# 1           None  24385788  https://ic.zigbang.com/ic/items/24385788/1.jpg
# 2           None  24430916  https://ic.zigbang.com/ic/items/24430916/1.jpg
# 3           None  24472349  https://ic.zigbang.com/ic/items/24472349/1.jpg
# 4           None  24081615  https://ic.zigbang.com/ic/items/24081615/1.jpg
# ..           ...       ...                                             ...
# 785         None  24481105  https://ic.zigbang.com/ic/items/24481105/1.jpg
# 786         None  24495639  https://ic.zigbang.com/ic/items/24495639/1.jpg
# 787         None  24552659  https://ic.zigbang.com/ic/items/24552659/1.jpg
# 788         None  24560234  https://ic.zigbang.com/ic/items/24560234/1.jpg
# 789         None  24188069  https://ic.zigbang.com/ic/items/24188069/1.jpg
#
#     sales_type sales_title  deposit  rent  size_m2                       공급면적  \
# 0           월세          월세     1000    47  22.1500  {'m2': 22.15, 'p': '6.7'}
# 1           월세          월세     1000    50  19.8300    {'m2': 19.83, 'p': '6'}
# 2           전세          전세     7000     0  16.5300    {'m2': 16.53, 'p': '5'}
# 3           전세          전세     9000     0  19.8300    {'m2': 19.83, 'p': '6'}
# 4           월세          월세     3000    30  19.8347    {'m2': 19.83, 'p': '6'}
# ..         ...         ...      ...   ...      ...                        ...
# 785         전세          전세    31000     0  48.0000    {'m2': 48, 'p': '14.5'}
# 786         전세          전세    31000     0  44.1000  {'m2': 44.1, 'p': '13.3'}
# 787         전세          전세    31000     0  56.2000    {'m2': 56.2, 'p': '17'}
# 788         전세          전세    31000     0  44.1000  {'m2': 44.1, 'p': '13.3'}
# 789         전세          전세    18000     0  33.0600   {'m2': 33.06, 'p': '10'}
#
#                           전용면적  계약면적 room_type_title floor floor_string  \
# 0    {'m2': 22.15, 'p': '6.7'}  None            None     5            5
# 1      {'m2': 19.83, 'p': '6'}  None            None     3            3
# 2      {'m2': 16.53, 'p': '5'}  None            None     4            4
# 3      {'m2': 19.83, 'p': '6'}  None            None     7            7
# 4      {'m2': 19.83, 'p': '6'}  None            None     5            5
# ..                         ...   ...             ...   ...          ...
# 785  {'m2': 29.95, 'p': '9.1'}  None            None     4            4
# 786   {'m2': 28.7, 'p': '8.7'}  None            None     4            4
# 787   {'m2': 46.28, 'p': '14'}  None            None     4            4
# 788   {'m2': 28.7, 'p': '8.7'}  None            None     4            4
# 789   {'m2': 33.06, 'p': '10'}  None            None     4            4
#
#     building_floor                             title is_first_movein  \
# 0                9        🌈당산역 신축 벽걸이TV까지 세련된 인테리어☀️            None
# 1                8        🌈🏡신축분리형🏡당산역5분🏡풀옵대형TV🏡채광최고🏡            None
# 2                8   영등포구청역♣ 근저당 없어 보증금 걱정뚝!! 대출안되요.            None
# 3                8       ※양평역 원룸 전세※ #전세대출 #대로변 #가성비            None
# 4                8      ♣당산동 원룸 가성비 갑!! 보증금 조절 가능!!♣            None
# ..             ...                               ...             ...
# 785              5  ㅇ여성 및 신혼부부 추천매물ㅇ투룸, 교통,편의시설 좋아요!            None
# 786              5     👣가좌역 6분 👌전세자금대출✨신축투룸 방2화1🌞채광굿            None
# 787              5  ㅇ여성 및 신혼부부 추천매물ㅇ투룸, 교통,편의시설 좋아요!            None
# 788              5     가좌역 초역세권 전망좋은 고급 2룸 신축 첫입주 전세            None
# 789              5  ♥[고래복층등장+러블리]♥가좌역5분♥EV+주차+완성형복충♥            None
#
#     room_type     address                                    random_location  \
# 0          02  영등포구 당산동4가  {'lat': 37.52958869987374, 'lng': 126.90039511...
# 1          02  영등포구 당산동4가  {'lat': 37.52959349211545, 'lng': 126.90044262...
# 2          01  영등포구 당산동4가  {'lat': 37.529607521960955, 'lng': 126.8976146...
# 3          01  영등포구 양평동3가  {'lat': 37.52959671442392, 'lng': 126.89071419...
# 4          01    영등포구 당산동  {'lat': 37.52968087892494, 'lng': 126.90668474...
# ..        ...         ...                                                ...
# 785        04      마포구 중동  {'lat': 37.56940355945648, 'lng': 126.90953258...
# 786        04      마포구 중동  {'lat': 37.56936875649569, 'lng': 126.90955413...
# 787        04      마포구 중동  {'lat': 37.56890602349362, 'lng': 126.90957581...
# 788        04      마포구 중동  {'lat': 37.568896834081684, 'lng': 126.9095717...
# 789        01      마포구 중동  {'lat': 37.56995706943952, 'lng': 126.90948156...
#
#      is_zzim  status service_type  tags        address1 address2 address3  \
# 0      False    True           원룸  [추천]  서울시 영등포구 당산동4가     None     None
# 1      False    True           원룸  [추천]  서울시 영등포구 당산동4가     None     None
# 2      False    True           원룸    []  서울시 영등포구 당산동4가     None     None
# 3      False    True           원룸    []  서울시 영등포구 양평동3가     None     None
# 4      False    True           원룸    []    서울시 영등포구 당산동     None     None
# ..       ...     ...          ...   ...             ...      ...      ...
# 785    False    True           빌라  [추천]      서울시 마포구 중동     None     None
# 786    False    True           빌라    []      서울시 마포구 중동     None     None
# 787    False    True           빌라  [추천]      서울시 마포구 중동     None     None
# 788    False    True           빌라  [추천]      서울시 마포구 중동     None     None
# 789    False    True           원룸    []      서울시 마포구 중동     None     None
#
#     manage_cost                   reg_date  is_new
# 0             7  2020-10-12T16:16:15+09:00   False
# 1             6  2020-10-26T11:15:07+09:00   False
# 2            13  2020-10-21T11:08:39+09:00   False
# 3            12  2020-10-23T17:18:06+09:00   False
# 4             6  2020-10-26T16:57:59+09:00   False
# ..          ...                        ...     ...
# 785           5  2020-10-24T13:50:02+09:00   False
# 786           5  2020-10-26T12:10:15+09:00   False
# 787           5  2020-10-29T23:05:53+09:00    True
# 788           5  2020-10-30T14:54:46+09:00    True
# 789           6  2020-10-26T20:07:57+09:00   False
#
# [790 rows x 30 columns]

# %%
# addr 데이터만 필터링
addr
result_df['address']
# Out:
# 0      영등포구 당산동4가
# 1      영등포구 당산동4가
# 2      영등포구 당산동4가
# 3      영등포구 양평동3가
# 4        영등포구 당산동
#           ...
# 785        마포구 중동
# 786        마포구 중동
# 787        마포구 중동
# 788        마포구 중동
# 789        마포구 중동
# Name: address, Length: 790, dtype: object

# %%
result_df['address'].str.contains(addr)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 785    False
# 786    False
# 787    False
# 788    False
# 789    False
# Name: address, Length: 790, dtype: bool

# %%
result_df = result_df[result_df['address'].str.contains(addr)] # 마스킹
result_df.reset_index(drop=True, inplace=True)
result_df.tail(2)
# Out:
#      item_id sales_type  deposit  rent  size_m2 floor building_floor  \
# 95  24415949         월세     1000    40    19.83     5              6
# 96  24468751         월세      200    50    16.53     1              3
#
#                            title  address manage_cost  \
# 95  ⭐⭐베란다 있는 원룸⭐주택가 조용⭐마포구청역3분⭐⭐  마포구 망원동           3
# 96   ⭐마포구청역⭐보증금조절,단기가능⭐신축급 풀옵션 ⭐  마포구 망원동           6
#
#                                       random_location
# 95  {'lat': 37.561227213691566, 'lng': 126.9018521...
# 96  {'lat': 37.56147374256839, 'lng': 126.90208971...

# %% [markdown]
# #### 함수로 만들기

# %%
def crawling_oneroom(addr):
    
    # 1. 동이름 > 위도, 경도
    url = "https://apis.zigbang.com/v2/search?q={}&serviceType=원룸".format(addr)
    response = requests.get(url)
    data = response.json()["items"][0]
    lat, lng = data["lat"], data["lng"]
    
    # 2. 위도, 경도 > geohash
    geohash = geohash2.encode(lat, lng, 5)
    
    # 3. geohash > item_ids
    url = "https://apis.zigbang.com/v2/items?\
deposit_gteq=0&domain=zigbang&geohash={}\
&rent_gteq=0&sales_type_in=전세|월세&service_type_eq=원룸".format(geohash)
    response = requests.get(url)
    datas = response.json()["items"]
    ids = [data["item_id"] for data in datas]
    
    # 4. item_ids > item datas
    url = "https://apis.zigbang.com/v2/items/list"
    params = {
        "domain": "zigbang",
        "item_ids": ids,
        "withCoalition": "true",
    }
    response = requests.post(url, data=params)
    items = response.json()["items"]
    item_df = pd.DataFrame(items)
    
    # 5. 데이터 전처리
    columns = ["item_id", "sales_type", "deposit", "rent", "size_m2",
          "floor", "building_floor", "title", "address",
           "manage_cost", "random_location"]
    result_df = item_df[columns]
    result_df = result_df[result_df["address"].str.contains(addr)]
    result_df.reset_index(drop=True, inplace=True)
    
    return result_df

# %%
df = crawling_oneroom('망원동')
df.tail(1)
# Out:
#      item_id sales_type  deposit  rent  size_m2 floor building_floor  \
# 95  24468751         월세      200    50    16.53     1              3
#
#                           title  address manage_cost  \
# 95  ⭐마포구청역⭐보증금조절,단기가능⭐신축급 풀옵션 ⭐  마포구 망원동           6
#
#                                       random_location
# 95  {'lat': 37.561975674678656, 'lng': 126.9020572...

# %%
df = crawling_oneroom('여의도동')
df.tail(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-63d006f4b417> in <module>
# ----> 1 df = crawling_oneroom('여의도동')
#       2 df.tail(1)
#
# <ipython-input-78-6b82aa49f70a> in crawling_oneroom(addr)
#      26     }
#      27     response = requests.post(url, data=params)
# ---> 28     items = response.json()["items"]
#      29     item_df = pd.DataFrame(items)
#      30
#
# KeyError: 'items'

# %% [markdown]
# - get방식 : 파라미터가 url에 포함
# - post방식 : 파라미터가 body에 포함
#     - request payload를 보면 확인할 수 있다
#     - url보다 훨씬 많은 데이터를 보낼 수 있다
#     - url은 글자수 제한이 있어서 많은 데이터를 담을 수는 없다
#     - 그럴 때 post방식 사용

# %% [markdown]
# #### 풀스택 프레임워크와 마이크로 프레임워크
# - 풀스택 : 프레임워크 안에 모든 기능을 가지고 있다는 의미
# - 마이크로 : 핵심적인 부분만 제공하는 프레임워크

# %% [markdown]
# #### 플라스크
# - 마이크로 프레임워크 기반

# %% [markdown]
# #### 1. flask 기본 사용법
# - 1.1. flask 모듈 임포트
# - pip install flask

# %%
# !pip install flask

# %%
from flask import Flask

# %% [markdown]
# #### 1.2 flask 객체를 app에 할당

# %%
app = Flask(__name__)
# 보통 app이란 이름으로 객체를 만든다

# %%
__name__
# Out:
# '__main__'

# %% [markdown]
# #### __name__ 이란?
# - __name__ 이란 변수는 모듈의 이름이 저장됨
# - 실행하는 코드에서는 __main__ 값이 들어감

# %% [markdown]
# #### 파이썬과 시작점(entry point)
# - 파이썬은 스크립트 언어
# - 스크립트 언어는 전통적으로 시작점없이 스크립트 코드를 바로 실행

# %% [markdown]
# #### flask 객체 생성
# - flask(__name__)으로 설정하여, 현재 위치를 flask 객체에 알려줘야 한다
#     - 이름을 변경해도 정상 실행되지만, 일부 확장 기능 사용시에는 해당 이름을 정확히 알려줘야 정상 동작

# %%
app
# Out:
# <Flask '__main__'>

# %% [markdown]
# #### 1.3 라우팅 경로를 설정

# %% [markdown]
# #### url

# %% [markdown]
# #### 라우팅(rounte)이란?
# - 적절한 목적지를 찾아주는 기능
# - url을 해당 url에 맞는 기능과 연결해 줌
#     - 예:
#         - http://www.fun-coding.org/hello
#         - http://www.fun-coding.org 서버에서 hello라는 목적지에 맞는 함수를 호출

# %%
# route는 반드시 '/' 로 시작
@app.route('/hello')
def hello():
    return '<h1>Hello Flask!</h1>'

# %% [markdown]
# #### 1.4 메인 모듈로 실행될 때 flask 웹 서버 구동
# - 서

# %%
run(host=None, port=None)
# Out:
# ERROR:root:File `'(host=None,.py'` not found.

# %%
host_addr = '0.0.0.0'
port_num = '8080'

# %%
if __name__ == '__main__':
    app.run(host=host_addr, port=port_num)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# INFO:werkzeug: * Running on http://0.0.0.0:8080/ (Press CTRL+C to quit)

# %% [markdown]
# #### 1.5 전체 기본 코드

# %%
from flask import Flask

app = flask(__name__)
@app.route('/hello')
def hello():
    return '<h1>Hello Flask!</h1>'

if __name__ == '__main__':
    app.run(host='127.0.0.1', port='8080')

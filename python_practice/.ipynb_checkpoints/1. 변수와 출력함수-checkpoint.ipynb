# %%
a=1.123456789123456789123456789
print(a)
# Out:
# 1.1234567891234568

# %% [markdown]
# - a라는 변수는 8바이트 용량까지만 저장할 수 있다
# - 8바이트가 넘어가면 데이터가 손실된다
# - 8바이트가 무엇인가?
#     - 64비트
# - 1바이트는 비트가 8개
# - 비트란?
#     - 0과 1을 저장할 수 있는 메모리 상의 공간

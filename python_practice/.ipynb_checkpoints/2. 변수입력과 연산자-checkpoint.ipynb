# %%
a, b = input('숫자를 입력하세요 : ').split()
# split은 띄어쓰기를 분리자로 해서 분리한다

print(a, b)
# Out:
# 숫자를 입력하세요 : 2 3
# 2 3

# %%
# map(func, *iterables)
a, b = map(int, input('숫자를 입력하세요 : ').split())
print(a+b)
# Out:
# 숫자를 입력하세요 : 2 3
# 5

# %%
a = 4.3
b = 5
c = a + b
print(type(c))

# 실수 > 정수.
# 형이 다른 것들이 연산을 하면 더 큰 범위에 있는 형으로 연산 결과가 나온다
# Out:
# <class 'float'>
